# %% [markdown]
# # **CELL 1 — SETUP**

# %%
# =============================================================
# CELL 1 — SETUP
# =============================================================

# Enable GPU status check
import tensorflow as tf
print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices("GPU"))

# Mount Google Drive FIRST (to avoid losing files)
from google.colab import drive
drive.mount('/content/drive')

# Create project directory (safe location)
import os
PROJECT_DIR = "/content/drive/MyDrive/AIML_4_Project"
os.makedirs(PROJECT_DIR, exist_ok=True)
print("Project directory:", PROJECT_DIR)

# Install required dependencies (ONLY ONCE)
# !pip install -q tensorflow tensorflow-datasets
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Mounted at /content/drive
# Project directory: /content/drive/MyDrive/AIML_4_Project

# %% [markdown]
# # **CELL 2 — MIXED PRECISION (faster GPU training)**

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy("mixed_float16")
print("Mixed precision enabled.")
# Out:
# Mixed precision enabled.

# %% [markdown]
# # **CELL 3 — LOAD STL-10 USING TFDS**

# %%
import tensorflow_datasets as tfds

ds_train, ds_test = tfds.load(
    "stl10",
    split=["train", "test"],
    as_supervised=False
)

print("TFDS STL-10 loaded successfully.")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/stl10/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/stl10/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/stl10/incomplete.MUTUU8_1.0.0/stl10-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/stl10/incomplete.MUTUU8_1.0.0/stl10-test.tfrecord*...:   0%|          | 0/…
# Generating unlabelled examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/stl10/incomplete.MUTUU8_1.0.0/stl10-unlabelled.tfrecord*...:   0%|        …
# Dataset stl10 downloaded and prepared to /root/tensorflow_datasets/stl10/1.0.0. Subsequent calls will reuse this data.
# TFDS STL-10 loaded successfully.

# %% [markdown]
# # **CELL 4 — DATA PIPELINE + NOISE GENERATION**

# %%
AUTOTUNE = tf.data.AUTOTUNE
IMG_SIZE = (96, 96)
BATCH_SIZE = 64

def preprocess(x):
    image = tf.cast(x["image"], tf.float32) / 255.0
    image = tf.image.resize(image, IMG_SIZE)
    return image

# Noise functions — PURE TF (FAST)
@tf.function
def gaussian_noise(img, std=0.1):
    noise = tf.random.normal(tf.shape(img), 0, std)
    return tf.clip_by_value(img + noise, 0, 1)

@tf.function
def salt_pepper(img, amount=0.02):
    rnd = tf.random.uniform(tf.shape(img))
    img = tf.where(rnd < amount/2, 1.0, img)
    img = tf.where((rnd >= amount/2) & (rnd < amount), 0.0, img)
    return img

@tf.function
def random_noise(img):
    r = tf.random.uniform([])
    return tf.cond(r < 0.5,
                   lambda: gaussian_noise(img),
                   lambda: salt_pepper(img))

def to_noisy_pair(img):
    noisy = random_noise(img)
    return noisy, img

# Build pipelines
train_pipeline = (
    ds_train.map(preprocess, AUTOTUNE)
            .cache()
            .shuffle(5000)
            .map(to_noisy_pair, AUTOTUNE)
            .batch(BATCH_SIZE)
            .prefetch(AUTOTUNE)
)

val_pipeline = (
    ds_test.map(preprocess, AUTOTUNE)
           .map(to_noisy_pair, AUTOTUNE)
           .batch(BATCH_SIZE)
           .prefetch(AUTOTUNE)
)

print("Data pipeline ready.")
# Out:
# Data pipeline ready.

# %% [markdown]
# # **CELL 5 — U-NET DENOISER (MODERN IMPLEMENTATION)**

# %%
from tensorflow.keras import layers, Model

def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x

def encoder_block(x, filters):
    s = conv_block(x, filters)
    p = layers.MaxPool2D()(s)
    return s, p

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 3, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

def build_unet(input_shape=(96,96,3), base=32):
    inputs = layers.Input(input_shape)

    s1, p1 = encoder_block(inputs, base)
    s2, p2 = encoder_block(p1, base*2)
    s3, p3 = encoder_block(p2, base*4)

    b = conv_block(p3, base*8)
    b = conv_block(b, base*8)

    d3 = decoder_block(b, s3, base*4)
    d2 = decoder_block(d3, s2, base*2)
    d1 = decoder_block(d2, s1, base)

    outputs = layers.Conv2D(3, 1, activation="sigmoid")(d1)
    return Model(inputs, outputs)

model = build_unet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 96, 96,    │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 96, 96,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 48, 48,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 48, 48,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 24, 24,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 24, 24,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 12, 12,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 12, 12,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 12, 12,    │    590,080 │ activation_3[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 24, 24,    │    295,040 │ activation_4[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 24, 24,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 24, 24,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 48, 48,    │     73,792 │ activation_5[0][… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 48, 48,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 48, 48,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 96, 96,    │     18,464 │ activation_6[0][… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 96, 96,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 96, 96,    │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 96, 96, 3) │         99 │ activation_7[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,757,027 (6.70 MB)
#  Trainable params: 1,755,107 (6.70 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# # **CELL 6 — COMPILE + CALLBACKS**

# %%
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)

SAVE_DIR = f"{PROJECT_DIR}/models"
os.makedirs(SAVE_DIR, exist_ok=True)

checkpoint_path = f"{SAVE_DIR}/best_model.keras"

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="mse"
)

callbacks = [
    ModelCheckpoint(checkpoint_path, save_best_only=True, monitor="val_loss", verbose=1),
    EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", patience=4, factor=0.5, verbose=1),
    CSVLogger(f"{SAVE_DIR}/training_log.csv")
]

print("Model compiled & callbacks ready.")
# Out:
# Model compiled & callbacks ready.

# %% [markdown]
# # **CELL 7 — TRAIN MODEL**

# %%
EPOCHS = 30

history = model.fit(
    train_pipeline,
    validation_data=val_pipeline,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0023
# Epoch 1: val_loss improved from 0.01639 to 0.00348, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 0.0023 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 2/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0021
# Epoch 2: val_loss improved from 0.00348 to 0.00237, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - loss: 0.0021 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 3/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0022
# Epoch 3: val_loss improved from 0.00237 to 0.00196, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 177ms/step - loss: 0.0022 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0021
# Epoch 4: val_loss did not improve from 0.00196
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - loss: 0.0021 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0021
# Epoch 5: val_loss did not improve from 0.00196
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - loss: 0.0021 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 6/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0020
# Epoch 6: val_loss did not improve from 0.00196
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - loss: 0.0020 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 7/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0020
# Epoch 7: val_loss improved from 0.00196 to 0.00176, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 167ms/step - loss: 0.0020 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0019
# Epoch 8: val_loss improved from 0.00176 to 0.00168, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - loss: 0.0019 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 9/30
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0018
# Epoch 9: val_loss improved from 0.00168 to 0.00164, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 178ms/step - loss: 0.0018 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0019
# Epoch 10: val_loss did not improve from 0.00164
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - loss: 0.0019 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 11/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0018
# Epoch 11: val_loss did not improve from 0.00164
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - loss: 0.0018 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 12/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0018
# Epoch 12: val_loss did not improve from 0.00164
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 168ms/step - loss: 0.0018 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 13/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0018
# Epoch 13: val_loss did not improve from 0.00164
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - loss: 0.0018 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 14/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0018
# Epoch 14: val_loss improved from 0.00164 to 0.00150, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - loss: 0.0018 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.00150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - loss: 0.0017 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 16/30
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0017
# Epoch 16: val_loss did not improve from 0.00150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - loss: 0.0017 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 17/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0017
# Epoch 17: val_loss did not improve from 0.00150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - loss: 0.0017 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 18/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0016
# Epoch 18: val_loss did not improve from 0.00150
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - loss: 0.0016 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 19/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0016
# Epoch 19: val_loss improved from 0.00150 to 0.00140, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 156ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 2.5000e-04
# Epoch 20/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0016
# Epoch 20: val_loss did not improve from 0.00140
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 167ms/step - loss: 0.0016 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 21/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0016
# Epoch 21: val_loss did not improve from 0.00140
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 2.5000e-04
# Epoch 22/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0017
# Epoch 22: val_loss did not improve from 0.00140
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - loss: 0.0017 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 23/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0016
# Epoch 23: val_loss improved from 0.00140 to 0.00139, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 24/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0016
# Epoch 24: val_loss improved from 0.00139 to 0.00136, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 25/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0015
# Epoch 25: val_loss did not improve from 0.00136
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 200ms/step - loss: 0.0015 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 26/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0016
# Epoch 26: val_loss did not improve from 0.00136
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 27/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0015
# Epoch 27: val_loss did not improve from 0.00136
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - loss: 0.0015 - val_loss: 0.0014 - learning_rate: 1.2500e-04
# Epoch 28/30
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0015
# Epoch 28: val_loss improved from 0.00136 to 0.00135, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - loss: 0.0015 - val_loss: 0.0014 - learning_rate: 6.2500e-05
# Epoch 29/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0015
# Epoch 29: val_loss improved from 0.00135 to 0.00135, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - loss: 0.0015 - val_loss: 0.0013 - learning_rate: 6.2500e-05
# Epoch 30/30
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0015
# Epoch 30: val_loss improved from 0.00135 to 0.00134, saving model to /content/drive/MyDrive/AIML_4_Project/models/best_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - loss: 0.0015 - val_loss: 0.0013 - learning_rate: 6.2500e-05

# %% [markdown]
# # **CELL 8 — PLOT TRAINING LOSS**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{SAVE_DIR}/loss_plot.png")
plt.show()

# %% [markdown]
# # **CELL 9 — VISUALIZE RESULTS**

# %%
# === FIXED CELL 9: convert float16 -> float32 for plotting ===
import numpy as np
import matplotlib.pyplot as plt

# Get a batch from val_pipeline (tf.Tensors)
noisy_batch, clean_batch = next(iter(val_pipeline))

# Make predictions (may be float16 if mixed precision is enabled)
preds = model.predict(noisy_batch)

# Convert to numpy and ensure dtype is float32 and values are in [0,1]
def to_np_float32(x):
    # handles tf.Tensor or numpy arrays (float16 -> float32)
    if hasattr(x, "numpy"):
        arr = x.numpy()
    else:
        arr = np.array(x)
    return arr.astype(np.float32)

noisy_np = to_np_float32(noisy_batch)
clean_np = to_np_float32(clean_batch)
preds_np  = to_np_float32(preds)

# Clip values to [0,1] just in case
noisy_np = np.clip(noisy_np, 0.0, 1.0)
clean_np = np.clip(clean_np, 0.0, 1.0)
preds_np  = np.clip(preds_np, 0.0, 1.0)

# Plot & save
plt.figure(figsize=(14,6))
for i in range(6):
    idx = np.random.randint(0, noisy_np.shape[0])

    plt.subplot(3, 6, i+1)
    plt.imshow(clean_np[idx])          # now float32 -> ok
    plt.title("Clean")
    plt.axis("off")

    plt.subplot(3, 6, 6+i+1)
    plt.imshow(noisy_np[idx])
    plt.title("Noisy")
    plt.axis("off")

    plt.subplot(3, 6, 12+i+1)
    plt.imshow(preds_np[idx])
    plt.title("Denoised")
    plt.axis("off")

plt.tight_layout()
plt.savefig(f"{SAVE_DIR}/sample_results.png", bbox_inches="tight")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step

# %% [markdown]
# # **CELL 10 — SAVE FINAL MODEL SAFELY**

# %%
model.save(f"{SAVE_DIR}/final_unet_denoiser.keras")
print("Final model saved to:", SAVE_DIR)
# Out:
# Final model saved to: /content/drive/MyDrive/AIML_4_Project/models

# %% [markdown]
# # **Prepare files inside Colab**

# %%
# !mkdir -p /content/aiml_upload/models
# !mkdir -p /content/aiml_upload/results

# !cp "/content/drive/MyDrive/Colab Notebooks/AIML_4_mohit.ipynb" /content/aiml_upload/
# !cp /content/drive/MyDrive/AIML_4_Project/models/*.keras /content/aiml_upload/models/
# !cp /content/drive/MyDrive/AIML_4_Project/models/*.csv /content/aiml_upload/models/

# !cp /content/drive/MyDrive/AIML_4_Project/models/*.png /content/aiml_upload/results/

# %%
# !ls -R /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive/:
# '2025-11-10 16-41-44.pdf'
#  6c0f06ac-9c15-43f0-b43f-a6f71ea07fcf.jpg
#  AIML_4_Project
#  AIML_Image_Denoiser
# 'CASE STUDY ASSIGNMENT.docx'
# 'changes b w AIML_4 and AIML_4_mohit.gdoc'
#  Classroom
# 'CNS Project ideas.gdoc'
# 'Colab Notebooks'
# 'Current resume_updated.pdf'
# 'Git Project.docx'
#  IMG-20240316-WA0004.jpg
# 'jpeg-optimizer_Adobe Scan 04 Oct 2023 (1)_1.jpg'
#  resume_visa.pdf
#  Screenshot_2024-03-22-16-17-05-79_40deb401b9ffe8e1df2f1cc5ba480b12.jpg
# 'UHV project.pdf'
#
# /content/drive/MyDrive/AIML_4_Project:
# models
#
# /content/drive/MyDrive/AIML_4_Project/models:
# best_model.keras	   loss_plot.png       training_log.csv
# final_unet_denoiser.keras  sample_results.png
#
# /content/drive/MyDrive/AIML_Image_Denoiser:
#
# /content/drive/MyDrive/Classroom:
# 'BE 4th Sem C'
#
# '/content/drive/MyDrive/Classroom/BE 4th Sem C':
#
# '/content/drive/MyDrive/Colab Notebooks':
# AIML_4_mohit.ipynb  mohit_1_AimlProject.ipynb  Untitled0.ipynb	Untitled1.ipynb
